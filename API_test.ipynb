# %%
# Common libraries
import matplotlib.pyplot as plt
from datetime import datetime
import requests
import json 
import pandas as pd

# %%
# Messari initialization
from messari.messari import Messari
m = Messari('cb0d3a33-c4c5-4b50-9fff-5dce65d44b97')

# Test messari
markets_df = m.get_all_markets()
markets_df.head(1)
# Out:
#                                                  id  \
# exchange_slug
# uniswap-v3     00029600-7335-4a57-94ff-87beffaf8b97
#
#                                         exchange_id  \
# exchange_slug
# uniswap-v3     65d7db09-764a-41a8-ac63-50a2d296f874
#
#                                       base_asset_id  \
# exchange_slug
# uniswap-v3     e23572af-c451-4bed-a085-361f9c207589
#
#                                      quote_asset_id trade_start trade_end  \
# exchange_slug
# uniswap-v3     4d7b4b96-ecd1-47f7-b8ec-c054dd78b7ed        None      None
#
#                version  excluded_from_price exchange_name base_asset_symbol  \
# exchange_slug
# uniswap-v3           1                 True  Uniswap (v3)               QBU
#
#               quote_asset_symbol      pair  price_usd  vwap_weight  \
# exchange_slug
# uniswap-v3                  WETH  QBU-WETH        NaN          1.0
#
#                volume_last_24_hours  has_real_volume  \
# exchange_slug
# uniswap-v3                      NaN             True
#
#                deviation_from_vwap_percent last_trade_at
# exchange_slug
# uniswap-v3                             NaN          None

# %%
# Coingecko initialization
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# Test coingecko
c = cg.get_coins_markets('usd')
c
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 41015,
#   'market_cap': 780892689634,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 862572968984,
#   'total_volume': 26354948522,
#   'high_24h': 41523,
#   'low_24h': 39765,
#   'price_change_24h': 984.28,
#   'price_change_percentage_24h': 2.4588,
#   'market_cap_change_24h': 21105739934,
#   'market_cap_change_percentage_24h': 2.77785,
#   'circulating_supply': 19011431.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -40.50975,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 60474.41237,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:24.561Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 3085.93,
#   'market_cap': 372001867235,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 16034617317,
#   'high_24h': 3146.96,
#   'low_24h': 3006.42,
#   'price_change_24h': 39.93,
#   'price_change_percentage_24h': 1.31086,
#   'market_cap_change_24h': 5640276707,
#   'market_cap_change_percentage_24h': 1.53954,
#   'circulating_supply': 120373923.874,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -36.6498,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 713650.2466,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 99.56178047364368,
#    'currency': 'btc',
#    'percentage': 9956.178047364367},
#   'last_updated': '2022-04-14T11:26:50.080Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 82725105863,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': None,
#   'total_volume': 51815128290,
#   'high_24h': 1.005,
#   'low_24h': 0.998934,
#   'price_change_24h': -0.001675733975,
#   'price_change_percentage_24h': -0.16725,
#   'market_cap_change_24h': 8244224,
#   'market_cap_change_percentage_24h': 0.00997,
#   'circulating_supply': 82648836091.1982,
#   'total_supply': 82648836091.1982,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.34991,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.82727,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:22:50.339Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1644979850',
#   'current_price': 418.56,
#   'market_cap': 70480678629,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 70480678629,
#   'total_volume': 1676160916,
#   'high_24h': 427.06,
#   'low_24h': 412.38,
#   'price_change_24h': 1.42,
#   'price_change_percentage_24h': 0.34079,
#   'market_cap_change_24h': 493237850,
#   'market_cap_change_percentage_24h': 0.70475,
#   'circulating_supply': 168137035.9,
#   'total_supply': 168137035.9,
#   'max_supply': 168137035.9,
#   'ath': 686.31,
#   'ath_change_percentage': -38.92148,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1052662.84886,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:35.756Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 0.999129,
#   'market_cap': 50265835226,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 5974159511,
#   'high_24h': 1.005,
#   'low_24h': 0.996522,
#   'price_change_24h': 0.00047197,
#   'price_change_percentage_24h': 0.04726,
#   'market_cap_change_24h': -290504331.88899994,
#   'market_cap_change_percentage_24h': -0.57462,
#   'circulating_supply': 50296998026.3572,
#   'total_supply': 50301533361.0074,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.77997,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 12.05727,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:17.683Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.724932,
#   'market_cap': 34927514657,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 72561260051,
#   'total_volume': 2965598970,
#   'high_24h': 0.740968,
#   'low_24h': 0.704841,
#   'price_change_24h': 0.01250059,
#   'price_change_percentage_24h': 1.75464,
#   'market_cap_change_24h': 695051675,
#   'market_cap_change_percentage_24h': 2.03039,
#   'circulating_supply': 48135209660.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -78.64872,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 26912.53819,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:38.849Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/solana.png?1640133422',
#   'current_price': 104.48,
#   'market_cap': 34301040600,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': None,
#   'total_volume': 1633130507,
#   'high_24h': 107.33,
#   'low_24h': 100.44,
#   'price_change_24h': 1.75,
#   'price_change_percentage_24h': 1.70055,
#   'market_cap_change_24h': 625743660,
#   'market_cap_change_percentage_24h': 1.85817,
#   'circulating_supply': 328054681.737068,
#   'total_supply': 508180963.57,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -59.77869,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 20778.3465,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:44.880Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 86.13,
#   'market_cap': 31209523522,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 86313826236,
#   'total_volume': 1929686537,
#   'high_24h': 89.68,
#   'low_24h': 83.52,
#   'price_change_24h': 1.54,
#   'price_change_percentage_24h': 1.81669,
#   'market_cap_change_24h': 1408151494,
#   'market_cap_change_percentage_24h': 4.72512,
#   'circulating_supply': 361581972.243057,
#   'total_supply': 745035751.669121,
#   'max_supply': 1000000000.0,
#   'ath': 119.18,
#   'ath_change_percentage': -27.62614,
#   'ath_date': '2022-04-05T12:24:58.854Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 70718.22086,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:56.602Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 0.958039,
#   'market_cap': 30770595125,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 43181560249,
#   'total_volume': 794546487,
#   'high_24h': 0.985357,
#   'low_24h': 0.938305,
#   'price_change_24h': 0.01078713,
#   'price_change_percentage_24h': 1.13878,
#   'market_cap_change_24h': 456601220,
#   'market_cap_change_percentage_24h': 1.50624,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -68.91422,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 4884.17307,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:00.503Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 79.67,
#   'market_cap': 21401206815,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 57433471024,
#   'total_volume': 735364375,
#   'high_24h': 81.74,
#   'low_24h': 76.03,
#   'price_change_24h': 2.36,
#   'price_change_percentage_24h': 3.05766,
#   'market_cap_change_24h': 693081890,
#   'market_cap_change_percentage_24h': 3.34691,
#   'circulating_supply': 268290748.096582,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -45.03582,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 2744.51682,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:21.734Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/polkadot.png?1639712644',
#   'current_price': 18.08,
#   'market_cap': 19946132140,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': None,
#   'total_volume': 499977034,
#   'high_24h': 18.49,
#   'low_24h': 17.45,
#   'price_change_24h': 0.425295,
#   'price_change_percentage_24h': 2.40945,
#   'market_cap_change_24h': 503751046,
#   'market_cap_change_percentage_24h': 2.59099,
#   'circulating_supply': 1102568818.32598,
#   'total_supply': 1183517323.95326,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -67.09543,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 570.67765,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:17.407Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.144477,
#   'market_cap': 19112934207,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': None,
#   'total_volume': 1123042600,
#   'high_24h': 0.145177,
#   'low_24h': 0.136941,
#   'price_change_24h': 0.00564795,
#   'price_change_percentage_24h': 4.06827,
#   'market_cap_change_24h': 725479454,
#   'market_cap_change_percentage_24h': 3.94551,
#   'circulating_supply': 132670764299.894,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -80.30793,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 165672.91727,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:27:00.305Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 0.999074,
#   'market_cap': 17434237436,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': None,
#   'total_volume': 3527541945,
#   'high_24h': 1.011,
#   'low_24h': 0.995788,
#   'price_change_24h': -0.002094233865,
#   'price_change_percentage_24h': -0.20918,
#   'market_cap_change_24h': -261282908.82823944,
#   'market_cap_change_percentage_24h': -1.47655,
#   'circulating_supply': 17437650158.48,
#   'total_supply': 17437650158.48,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.37716,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 10.95041,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:27.699Z'},
#  {'id': 'terrausd',
#   'symbol': 'ust',
#   'name': 'TerraUSD',
#   'image': 'https://assets.coingecko.com/coins/images/12681/large/UST.png?1601612407',
#   'current_price': 1.003,
#   'market_cap': 17072845656,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': None,
#   'total_volume': 599921020,
#   'high_24h': 1.006,
#   'low_24h': 0.99763,
#   'price_change_24h': 0.00214014,
#   'price_change_percentage_24h': 0.21374,
#   'market_cap_change_24h': 142394497,
#   'market_cap_change_percentage_24h': 0.84106,
#   'circulating_supply': 17026513087.8582,
#   'total_supply': 17023652895.5472,
#   'max_supply': None,
#   'ath': 1.092,
#   'ath_change_percentage': -8.16468,
#   'ath_date': '2021-01-11T22:30:57.984Z',
#   'atl': 0.857992,
#   'atl_change_percentage': 16.87244,
#   'atl_date': '2021-05-19T13:14:26.898Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:13.075Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 2.64e-05,
#   'market_cap': 14537942646,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 1378276650,
#   'high_24h': 2.696e-05,
#   'low_24h': 2.579e-05,
#   'price_change_24h': -2.74035e-07,
#   'price_change_percentage_24h': -1.0273,
#   'market_cap_change_24h': -64476115.65379143,
#   'market_cap_change_percentage_24h': -0.44154,
#   'circulating_supply': 549146987315505.4,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -69.30591,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 46917324.90059,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:03.314Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near_icon.png?1601359077',
#   'current_price': 17.35,
#   'market_cap': 11633822752,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 17412222507,
#   'total_volume': 1194212959,
#   'high_24h': 17.72,
#   'low_24h': 15.66,
#   'price_change_24h': 1.49,
#   'price_change_percentage_24h': 9.36642,
#   'market_cap_change_24h': 1010259286,
#   'market_cap_change_percentage_24h': 9.50961,
#   'circulating_supply': 668141171.923176,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 20.44,
#   'ath_change_percentage': -15.06595,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 3195.39895,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:50.307Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 41102,
#   'market_cap': 11393355372,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 11393355372,
#   'total_volume': 314453625,
#   'high_24h': 41518,
#   'low_24h': 39743,
#   'price_change_24h': 1123.01,
#   'price_change_percentage_24h': 2.80902,
#   'market_cap_change_24h': 348905236,
#   'market_cap_change_percentage_24h': 3.1591,
#   'circulating_supply': 277178.99108794,
#   'total_supply': 277178.99108794,
#   'max_supply': 277178.99108794,
#   'ath': 70643,
#   'ath_change_percentage': -41.79272,
#   'ath_date': '2021-11-10T14:40:19.650Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1209.88646,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:33.643Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/oCw2s3GI_400x400.jpeg?1645172042',
#   'current_price': 0.420014,
#   'market_cap': 10620191788,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': None,
#   'total_volume': 54218272,
#   'high_24h': 0.426951,
#   'low_24h': 0.408652,
#   'price_change_24h': 0.00475675,
#   'price_change_percentage_24h': 1.1455,
#   'market_cap_change_24h': 143532020,
#   'market_cap_change_percentage_24h': 1.37002,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -56.45516,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 3368.63817,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:58.718Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 3082.87,
#   'market_cap': 10207593899,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 10207593899,
#   'total_volume': 32921337,
#   'high_24h': 3141.88,
#   'low_24h': 3005.14,
#   'price_change_24h': 40.17,
#   'price_change_percentage_24h': 1.32012,
#   'market_cap_change_24h': 310443393,
#   'market_cap_change_percentage_24h': 3.13669,
#   'circulating_supply': 3308458.38370134,
#   'total_supply': 3308458.38370134,
#   'max_supply': 3308458.38370134,
#   'ath': 4829.57,
#   'ath_change_percentage': -36.1832,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 538.24836,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:10.073Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 1.4,
#   'market_cap': 9638747506,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 14024300223,
#   'total_volume': 617500000,
#   'high_24h': 1.44,
#   'low_24h': 1.37,
#   'price_change_24h': -0.003111813697,
#   'price_change_percentage_24h': -0.22163,
#   'market_cap_change_24h': -5423492.562269211,
#   'market_cap_change_percentage_24h': -0.05624,
#   'circulating_supply': 6872890164.27,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.92,
#   'ath_change_percentage': -51.91007,
#   'ath_date': '2021-12-27T02:08:34.307Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 44509.91594,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 531.6841903769647,
#    'currency': 'usd',
#    'percentage': 53168.41903769646},
#   'last_updated': '2022-04-14T11:26:19.662Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/4943.png?1636636734',
#   'current_price': 1.0,
#   'market_cap': 8818880440,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 8818880440,
#   'total_volume': 322921011,
#   'high_24h': 1.005,
#   'low_24h': 0.998574,
#   'price_change_24h': -0.000151348622,
#   'price_change_percentage_24h': -0.01513,
#   'market_cap_change_24h': 79787659,
#   'market_cap_change_percentage_24h': 0.913,
#   'circulating_supply': 8812632004.71752,
#   'total_supply': 8812632004.71752,
#   'max_supply': 8812632004.71752,
#   'ath': 1.22,
#   'ath_change_percentage': -17.9027,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.79067,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:22:45.921Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 109.64,
#   'market_cap': 7688298419,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 9217152991,
#   'total_volume': 758295672,
#   'high_24h': 112.26,
#   'low_24h': 106.92,
#   'price_change_24h': 2.72,
#   'price_change_percentage_24h': 2.54458,
#   'market_cap_change_24h': 229121417,
#   'market_cap_change_percentage_24h': 3.07167,
#   'circulating_supply': 70066870.7334713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -73.25422,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 9451.10899,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:18.951Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 24.55,
#   'market_cap': 7192802743,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': None,
#   'total_volume': 482706242,
#   'high_24h': 25.16,
#   'low_24h': 24.21,
#   'price_change_24h': -0.057955157164,
#   'price_change_percentage_24h': -0.23554,
#   'market_cap_change_24h': 2662968,
#   'market_cap_change_percentage_24h': 0.03704,
#   'circulating_supply': 292586163.827428,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 44.45,
#   'ath_change_percentage': -44.69113,
#   'ath_date': '2022-01-17T00:34:41.497Z',
#   'atl': 1.16,
#   'atl_change_percentage': 2019.17699,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 244.4740246297916,
#    'currency': 'usd',
#    'percentage': 24447.40246297916},
#   'last_updated': '2022-04-14T11:26:11.146Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 13.97,
#   'market_cap': 6541490128,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 14007187080,
#   'total_volume': 512336621,
#   'high_24h': 14.33,
#   'low_24h': 13.72,
#   'price_change_24h': 0.086117,
#   'price_change_percentage_24h': 0.62025,
#   'market_cap_change_24h': 66068841,
#   'market_cap_change_percentage_24h': 1.0203,
#   'circulating_supply': 467009549.5205637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -73.41908,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 9352.65276,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:34.223Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 339.5,
#   'market_cap': 6471550127,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 7139149919,
#   'total_volume': 971398300,
#   'high_24h': 350.76,
#   'low_24h': 314.86,
#   'price_change_24h': 24.64,
#   'price_change_percentage_24h': 7.82571,
#   'market_cap_change_24h': 588361341,
#   'market_cap_change_percentage_24h': 10.00072,
#   'circulating_supply': 19036237.3966517,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -91.02019,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 341.88006,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:20.953Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.061447,
#   'market_cap': 6265774907,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': None,
#   'total_volume': 1024948185,
#   'high_24h': 0.061986,
#   'low_24h': 0.059985,
#   'price_change_24h': 0.00105028,
#   'price_change_percentage_24h': 1.73897,
#   'market_cap_change_24h': 127727405,
#   'market_cap_change_percentage_24h': 2.08091,
#   'circulating_supply': 101657733022.815,
#   'total_supply': 101900409184.273,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -73.38633,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 3317.12554,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 31.34068499373404,
#    'currency': 'usd',
#    'percentage': 3134.0684993734044},
#   'last_updated': '2022-04-14T11:25:08.672Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 42.78,
#   'market_cap': 5866763908,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 14250050726,
#   'total_volume': 46797708,
#   'high_24h': 43.33,
#   'low_24h': 41.46,
#   'price_change_24h': 0.903729,
#   'price_change_percentage_24h': 2.15794,
#   'market_cap_change_24h': 136328898,
#   'market_cap_change_percentage_24h': 2.37903,
#   'circulating_supply': 137072627.51874423,
#   'total_supply': 332941963.585972,
#   'max_supply': 332941963.585972,
#   'ath': 84.18,
#   'ath_change_percentage': -49.21342,
#   'ath_date': '2021-09-09T16:59:43.151Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3618.59786,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:14.473Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1558326215',
#   'current_price': 5.74,
#   'market_cap': 5366131717,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 2448464,
#   'high_24h': 5.81,
#   'low_24h': 5.64,
#   'price_change_24h': 0.0209142,
#   'price_change_percentage_24h': 0.36575,
#   'market_cap_change_24h': -31213148.82606697,
#   'market_cap_change_percentage_24h': -0.57831,
#   'circulating_supply': 936479128.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 8.14,
#   'ath_change_percentage': -29.4525,
#   'ath_date': '2022-02-08T17:40:10.285Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 617.53655,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:50.932Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1642471050',
#   'current_price': 20.0,
#   'market_cap': 5243728127,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 83929578,
#   'high_24h': 20.9,
#   'low_24h': 18.93,
#   'price_change_24h': 0.955538,
#   'price_change_percentage_24h': 5.01679,
#   'market_cap_change_24h': 273213107,
#   'market_cap_change_percentage_24h': 5.49668,
#   'circulating_supply': 260143733.83,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -54.19406,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 3371.71275,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:13.511Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 37.96,
#   'market_cap': 5095664138,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 8000453822,
#   'total_volume': 545577296,
#   'high_24h': 39.17,
#   'low_24h': 37.16,
#   'price_change_24h': 0.170763,
#   'price_change_percentage_24h': 0.45183,
#   'market_cap_change_24h': 46704770,
#   'market_cap_change_percentage_24h': 0.92504,
#   'circulating_supply': 134199441.407502,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -77.27459,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 6073.73719,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 83.36629432744165,
#    'currency': 'usd',
#    'percentage': 8336.629432744165},
#   'last_updated': '2022-04-14T11:25:54.464Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 0.743102,
#   'market_cap': 4989363458,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 7436526650,
#   'total_volume': 179422007,
#   'high_24h': 0.759659,
#   'low_24h': 0.716715,
#   'price_change_24h': 0.01265251,
#   'price_change_percentage_24h': 1.73215,
#   'market_cap_change_24h': 97820216,
#   'market_cap_change_percentage_24h': 1.99978,
#   'circulating_supply': 6709265888.258,
#   'total_supply': 7140115648.2326,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -79.11765,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 605.98478,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.6903743390584764,
#    'currency': 'usd',
#    'percentage': -69.03743390584765},
#   'last_updated': '2022-04-14T11:25:24.713Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.196702,
#   'market_cap': 4868710159,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 9840308016,
#   'total_volume': 266669822,
#   'high_24h': 0.200273,
#   'low_24h': 0.193078,
#   'price_change_24h': 0.00263885,
#   'price_change_percentage_24h': 1.35979,
#   'market_cap_change_24h': 88178214,
#   'market_cap_change_percentage_24h': 1.84453,
#   'circulating_supply': 24739491125.6857,
#   'total_supply': 50001787922.1316,
#   'max_supply': 50001787922.1316,
#   'ath': 0.875563,
#   'ath_change_percentage': -77.52313,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 41233.63881,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:37.939Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 9.62,
#   'market_cap': 4394845709,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 9627483010,
#   'total_volume': 196145376,
#   'high_24h': 9.75,
#   'low_24h': 9.31,
#   'price_change_24h': 0.182676,
#   'price_change_percentage_24h': 1.93666,
#   'market_cap_change_24h': 101645554,
#   'market_cap_change_percentage_24h': 2.36759,
#   'circulating_supply': 456489583.4010546,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -78.58766,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 833.63211,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:44.635Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 233.52,
#   'market_cap': 4239808853,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': None,
#   'total_volume': 236273741,
#   'high_24h': 240.18,
#   'low_24h': 229.63,
#   'price_change_24h': 0.527135,
#   'price_change_percentage_24h': 0.22625,
#   'market_cap_change_24h': 24296316,
#   'market_cap_change_percentage_24h': 0.57635,
#   'circulating_supply': 18107266.8927224,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -56.8249,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 108213.998,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:08.328Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.062661,
#   'market_cap': 4191718779,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 344968615,
#   'high_24h': 0.064021,
#   'low_24h': 0.05915,
#   'price_change_24h': 0.00277777,
#   'price_change_percentage_24h': 4.63865,
#   'market_cap_change_24h': 207664136,
#   'market_cap_change_percentage_24h': 5.21238,
#   'circulating_supply': 66760741299.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -77.6551,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 3175.05552,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 6.106728975923887,
#    'currency': 'eth',
#    'percentage': 610.6728975923887},
#   'last_updated': '2022-04-14T11:25:18.406Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1637045634',
#   'current_price': 0.201256,
#   'market_cap': 4039126888,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': None,
#   'total_volume': 44789783,
#   'high_24h': 0.205921,
#   'low_24h': 0.198057,
#   'price_change_24h': 0.00119197,
#   'price_change_percentage_24h': 0.59579,
#   'market_cap_change_24h': 31942074,
#   'market_cap_change_percentage_24h': 0.79712,
#   'circulating_supply': 20058481700.0,
#   'total_supply': 50000000000.0,
#   'max_supply': None,
#   'ath': 0.569229,
#   'ath_change_percentage': -64.62451,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 1942.03705,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:01.404Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 16.84,
#   'market_cap': 3785182927,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 7914471494,
#   'total_volume': 123863338,
#   'high_24h': 17.31,
#   'low_24h': 16.27,
#   'price_change_24h': 0.307999,
#   'price_change_percentage_24h': 1.86297,
#   'market_cap_change_24h': 98599773,
#   'market_cap_change_percentage_24h': 2.67456,
#   'circulating_supply': 224406610.815526,
#   'total_supply': 479920691.199589,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -97.59529,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 14.88,
#   'atl_change_percentage': 13.23748,
#   'atl_date': '2022-02-24T07:39:52.750Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:16.829Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 19.22,
#   'market_cap': 3725681740,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 37920468555,
#   'total_volume': 245213330,
#   'high_24h': 19.74,
#   'low_24h': 18.85,
#   'price_change_24h': 0.097474,
#   'price_change_percentage_24h': 0.50963,
#   'market_cap_change_24h': 109370590,
#   'market_cap_change_percentage_24h': 3.02437,
#   'circulating_supply': 193576266.0,
#   'total_supply': 1970244165.0,
#   'max_supply': 1970244165.0,
#   'ath': 236.84,
#   'ath_change_percentage': -91.87885,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 16.54,
#   'atl_change_percentage': 16.26927,
#   'atl_date': '2022-03-15T09:10:51.762Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:26.037Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 47.88,
#   'market_cap': 3711828454,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 12951497554,
#   'total_volume': 349078064,
#   'high_24h': 49.53,
#   'low_24h': 47.01,
#   'price_change_24h': -0.029213052832,
#   'price_change_percentage_24h': -0.06097,
#   'market_cap_change_24h': 16013656,
#   'market_cap_change_percentage_24h': 0.43329,
#   'circulating_supply': 77380525.17332055,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 164.9,
#   'ath_change_percentage': -70.91014,
#   'ath_date': '2021-11-06T19:29:29.482Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 38672.42181,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:50.744Z'},
#  {'id': 'apecoin',
#   'symbol': 'ape',
#   'name': 'ApeCoin',
#   'image': 'https://assets.coingecko.com/coins/images/24383/large/apecoin.jpg?1647476455',
#   'current_price': 13.18,
#   'market_cap': 3672488114,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 13234191403,
#   'total_volume': 1032902926,
#   'high_24h': 13.45,
#   'low_24h': 11.94,
#   'price_change_24h': 1.029,
#   'price_change_percentage_24h': 8.46501,
#   'market_cap_change_24h': 298378158,
#   'market_cap_change_percentage_24h': 8.84317,
#   'circulating_supply': 277500000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 17.17,
#   'ath_change_percentage': -23.22573,
#   'ath_date': '2022-03-18T08:54:13.923Z',
#   'atl': 6.21,
#   'atl_change_percentage': 112.12449,
#   'atl_date': '2022-03-17T13:30:22.320Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:35.274Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 159.66,
#   'market_cap': 3544956658,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': None,
#   'total_volume': 88236256,
#   'high_24h': 163.36,
#   'low_24h': 154.56,
#   'price_change_24h': 2.22,
#   'price_change_percentage_24h': 1.4109,
#   'market_cap_change_24h': 51072040,
#   'market_cap_change_percentage_24h': 1.46176,
#   'circulating_supply': 22179418.0,
#   'total_supply': 23509418.0,
#   'max_supply': None,
#   'ath': 545.64,
#   'ath_change_percentage': -70.70758,
#   'ath_date': '2021-11-23T10:33:26.737Z',
#   'atl': 6.51,
#   'atl_change_percentage': 2356.42078,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:49.362Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 2.17,
#   'market_cap': 3300219148,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 4774113079,
#   'total_volume': 230571477,
#   'high_24h': 2.24,
#   'low_24h': 2.12,
#   'price_change_24h': 0.0285563,
#   'price_change_percentage_24h': 1.33168,
#   'market_cap_change_24h': 50887018,
#   'market_cap_change_percentage_24h': 1.56608,
#   'circulating_supply': 1516447841.9344337,
#   'total_supply': 2193700827.32015,
#   'max_supply': 2193700827.32015,
#   'ath': 5.85,
#   'ath_change_percentage': -62.80381,
#   'ath_date': '2021-11-25T10:04:18.534Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 23460.98206,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 107.6471124101239,
#    'currency': 'usd',
#    'percentage': 10764.71124101239},
#   'last_updated': '2022-04-14T11:25:11.011Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1597397942',
#   'current_price': 2.83,
#   'market_cap': 3279192432,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 8492106219,
#   'total_volume': 290097673,
#   'high_24h': 2.93,
#   'low_24h': 2.76,
#   'price_change_24h': 0.03381728,
#   'price_change_percentage_24h': 1.2088,
#   'market_cap_change_24h': 40501738,
#   'market_cap_change_percentage_24h': 1.25056,
#   'circulating_supply': 1158437853.2233226,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -66.33273,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 9655.7002,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:11.130Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 61.97,
#   'market_cap': 3224571041,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 153.66,
#   'high_24h': 63.13,
#   'low_24h': 60.46,
#   'price_change_24h': 0.948305,
#   'price_change_percentage_24h': 1.5541,
#   'market_cap_change_24h': 66609416,
#   'market_cap_change_percentage_24h': 2.10925,
#   'circulating_supply': 52036200.2517807,
#   'total_supply': 52036200.2517807,
#   'max_supply': None,
#   'ath': 97.75,
#   'ath_change_percentage': -36.60615,
#   'ath_date': '2021-11-21T12:39:57.508Z',
#   'atl': 1.89,
#   'atl_change_percentage': 3185.17368,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:55.442Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 3.15,
#   'market_cap': 3153606752,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': None,
#   'total_volume': 129300072,
#   'high_24h': 3.22,
#   'low_24h': 3.0,
#   'price_change_24h': 0.083722,
#   'price_change_percentage_24h': 2.73119,
#   'market_cap_change_24h': 99466799,
#   'market_cap_change_percentage_24h': 3.25679,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -79.93853,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 7705.99699,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 19.994065976367747,
#    'currency': 'usd',
#    'percentage': 1999.4065976367747},
#   'last_updated': '2022-04-14T11:25:23.133Z'},
#  {'id': 'fantom',
#   'symbol': 'ftm',
#   'name': 'Fantom',
#   'image': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#   'current_price': 1.2,
#   'market_cap': 3051324161,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 3812425004,
#   'total_volume': 411426680,
#   'high_24h': 1.22,
#   'low_24h': 1.15,
#   'price_change_24h': 0.02317567,
#   'price_change_percentage_24h': 1.97324,
#   'market_cap_change_24h': 85084818,
#   'market_cap_change_percentage_24h': 2.86844,
#   'circulating_supply': 2541152731.01,
#   'total_supply': 3175000000.0,
#   'max_supply': 3175000000.0,
#   'ath': 3.46,
#   'ath_change_percentage': -65.28153,
#   'ath_date': '2021-10-28T05:19:39.845Z',
#   'atl': 0.00190227,
#   'atl_change_percentage': 63022.68718,
#   'atl_date': '2020-03-13T02:25:38.280Z',
#   'roi': {'times': 38.92242092660833,
#    'currency': 'usd',
#    'percentage': 3892.2420926608334},
#   'last_updated': '2022-04-14T11:26:52.492Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 3.23,
#   'market_cap': 2843769307,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': None,
#   'total_volume': 155492898,
#   'high_24h': 3.28,
#   'low_24h': 3.06,
#   'price_change_24h': 0.140977,
#   'price_change_percentage_24h': 4.56465,
#   'market_cap_change_24h': 126708391,
#   'market_cap_change_percentage_24h': 4.66344,
#   'circulating_supply': 883393371.529282,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 9.12,
#   'ath_change_percentage': -64.68714,
#   'ath_date': '2021-10-04T00:41:18.025Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 818.5059,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 5.871114424031587,
#    'currency': 'usd',
#    'percentage': 587.1114424031588},
#   'last_updated': '2022-04-14T11:26:51.308Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/klaytn.jpeg?1642775250',
#   'current_price': 1.008,
#   'market_cap': 2804756482,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': None,
#   'total_volume': 32712944,
#   'high_24h': 1.044,
#   'low_24h': 1.004,
#   'price_change_24h': -0.001462228762,
#   'price_change_percentage_24h': -0.14484,
#   'market_cap_change_24h': -536098.4287290573,
#   'market_cap_change_percentage_24h': -0.01911,
#   'circulating_supply': 2782454942.2,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -76.76801,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 1567.80725,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:10.079Z'},
#  {'id': 'magic-internet-money',
#   'symbol': 'mim',
#   'name': 'Magic Internet Money',
#   'image': 'https://assets.coingecko.com/coins/images/16786/large/mimlogopng.png?1624979612',
#   'current_price': 1.0,
#   'market_cap': 2782459149,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': None,
#   'total_volume': 25061895,
#   'high_24h': 1.005,
#   'low_24h': 0.995597,
#   'price_change_24h': -0.000653750838,
#   'price_change_percentage_24h': -0.06532,
#   'market_cap_change_24h': -5206378.344165802,
#   'market_cap_change_percentage_24h': -0.18676,
#   'circulating_supply': 2785296692.97944,
#   'total_supply': 2785296692.97944,
#   'max_supply': None,
#   'ath': 1.041,
#   'ath_change_percentage': -4.03748,
#   'ath_date': '2021-10-06T13:25:17.751Z',
#   'atl': 0.919196,
#   'atl_change_percentage': 8.68438,
#   'atl_date': '2021-12-04T05:29:56.806Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:08.811Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Frax',
#   'image': 'https://assets.coingecko.com/coins/images/13422/large/frax_logo.png?1608476506',
#   'current_price': 0.999335,
#   'market_cap': 2697083906,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 2697083906,
#   'total_volume': 62160103,
#   'high_24h': 1.004,
#   'low_24h': 0.998416,
#   'price_change_24h': -0.00231987677,
#   'price_change_percentage_24h': -0.2316,
#   'market_cap_change_24h': -3549494.4875273705,
#   'market_cap_change_percentage_24h': -0.13143,
#   'circulating_supply': 2697095597.84012,
#   'total_supply': 2697095597.84012,
#   'max_supply': 2697095597.84012,
#   'ath': 1.14,
#   'ath_change_percentage': -12.38448,
#   'ath_date': '2021-02-07T12:55:35.766Z',
#   'atl': 0.891635,
#   'atl_change_percentage': 12.06514,
#   'atl_date': '2021-12-04T05:33:57.315Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:58.076Z'},
#  {'id': 'thorchain',
#   'symbol': 'rune',
#   'name': 'THORChain',
#   'image': 'https://assets.coingecko.com/coins/images/6595/large/RUNE.png?1614160507',
#   'current_price': 8.9,
#   'market_cap': 2683067438,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 4460550743,
#   'total_volume': 316806469,
#   'high_24h': 9.34,
#   'low_24h': 7.47,
#   'price_change_24h': 1.19,
#   'price_change_percentage_24h': 15.39339,
#   'market_cap_change_24h': 369780430,
#   'market_cap_change_percentage_24h': 15.98506,
#   'circulating_supply': 300755174.9386705,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 20.87,
#   'ath_change_percentage': -57.32362,
#   'ath_date': '2021-05-19T00:30:09.436Z',
#   'atl': 0.00851264,
#   'atl_change_percentage': 104515.31009,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 233.11608040125256,
#    'currency': 'usd',
#    'percentage': 23311.608040125255},
#   'last_updated': '2022-04-14T11:24:59.642Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.377958,
#   'market_cap': 2533352793,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 3782663909,
#   'total_volume': 161708995,
#   'high_24h': 0.390719,
#   'low_24h': 0.364314,
#   'price_change_24h': 0.00525572,
#   'price_change_percentage_24h': 1.41016,
#   'market_cap_change_24h': 47337283,
#   'market_cap_change_percentage_24h': 1.90414,
#   'circulating_supply': 6697271696.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -86.68776,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 266.34592,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:44.088Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 173.66,
#   'market_cap': 2376008384,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 2778821209,
#   'total_volume': 297775489,
#   'high_24h': 180.1,
#   'low_24h': 163.32,
#   'price_change_24h': 7.26,
#   'price_change_percentage_24h': 4.36227,
#   'market_cap_change_24h': 103427395,
#   'market_cap_change_percentage_24h': 4.5511,
#   'circulating_supply': 13680669.35187705,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -73.76727,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 567.01902,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:27.947Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://assets.coingecko.com/coins/images/12632/large/pancakeswap-cake-logo_%281%29.png?1629359065',
#   'current_price': 8.18,
#   'market_cap': 2336266704,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 139351700,
#   'high_24h': 8.33,
#   'low_24h': 7.94,
#   'price_change_24h': 0.125771,
#   'price_change_percentage_24h': 1.56179,
#   'market_cap_change_24h': 46147875,
#   'market_cap_change_percentage_24h': 2.01509,
#   'circulating_supply': 285297095.984892,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 43.96,
#   'ath_change_percentage': -81.3739,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 4111.51416,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:35.298Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 2.31,
#   'market_cap': 2295337676,
#   'market_cap_rank': 55,
# ...
#   'image': 'https://assets.coingecko.com/coins/images/1102/large/enjin-coin-logo.png?1547035078',
#   'current_price': 1.56,
#   'market_cap': 1455392891,
#   'market_cap_rank': 83,
#   'fully_diluted_valuation': 1557668369,
#   'total_volume': 138301379,
#   'high_24h': 1.62,
#   'low_24h': 1.54,
#   'price_change_24h': -0.005382640515,
#   'price_change_percentage_24h': -0.3446,
#   'market_cap_change_24h': 1617361,
#   'market_cap_change_percentage_24h': 0.11125,
#   'circulating_supply': 934340659.567558,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.82,
#   'ath_change_percentage': -67.67876,
#   'ath_date': '2021-11-25T09:53:41.955Z',
#   'atl': 0.01865964,
#   'atl_change_percentage': 8247.79305,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:01.298Z'},
#  {'id': 'celo',
#   'symbol': 'celo',
#   'name': 'Celo',
#   'image': 'https://assets.coingecko.com/coins/images/11090/large/icon-celo-CELO-color-500.png?1592293590',
#   'current_price': 3.29,
#   'market_cap': 1428967511,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 3298532739,
#   'total_volume': 80255377,
#   'high_24h': 3.37,
#   'low_24h': 3.11,
#   'price_change_24h': 0.105025,
#   'price_change_percentage_24h': 3.29242,
#   'market_cap_change_24h': 48573474,
#   'market_cap_change_percentage_24h': 3.51881,
#   'circulating_supply': 433213075.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 9.82,
#   'ath_change_percentage': -66.41451,
#   'ath_date': '2021-08-30T14:25:09.929Z',
#   'atl': 0.800156,
#   'atl_change_percentage': 312.23638,
#   'atl_date': '2020-05-22T04:15:27.736Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:50.149Z'},
#  {'id': 'radix',
#   'symbol': 'xrd',
#   'name': 'Radix',
#   'image': 'https://assets.coingecko.com/coins/images/4374/large/Radix.png?1629701658',
#   'current_price': 0.138137,
#   'market_cap': 1359793699,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 3317346271,
#   'total_volume': 327681,
#   'high_24h': 0.139367,
#   'low_24h': 0.131229,
#   'price_change_24h': 0.00639488,
#   'price_change_percentage_24h': 4.8541,
#   'market_cap_change_24h': 64644134,
#   'market_cap_change_percentage_24h': 4.99125,
#   'circulating_supply': 9837697397.7162,
#   'total_supply': 12237674427.8512,
#   'max_supply': 24000000000.0,
#   'ath': 0.651264,
#   'ath_change_percentage': -78.77622,
#   'ath_date': '2021-11-14T16:09:27.130Z',
#   'atl': 0.086235,
#   'atl_change_percentage': 60.28565,
#   'atl_date': '2021-09-13T04:50:07.104Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:23:46.195Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 0.999685,
#   'market_cap': 1352757480,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': None,
#   'total_volume': 99212016,
#   'high_24h': 1.006,
#   'low_24h': 0.99686,
#   'price_change_24h': -0.000412417318,
#   'price_change_percentage_24h': -0.04124,
#   'market_cap_change_24h': -10842374.036298752,
#   'market_cap_change_percentage_24h': -0.79513,
#   'circulating_supply': 1353519867.41464,
#   'total_supply': 1353519867.41464,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.24968,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.11606,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:42.090Z'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'image': 'https://assets.coingecko.com/coins/images/3695/large/nexo.png?1548086057',
#   'current_price': 2.41,
#   'market_cap': 1352531467,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 2415234720,
#   'total_volume': 18063994,
#   'high_24h': 2.45,
#   'low_24h': 2.28,
#   'price_change_24h': 0.070323,
#   'price_change_percentage_24h': 2.99981,
#   'market_cap_change_24h': 31583481,
#   'market_cap_change_percentage_24h': 2.39097,
#   'circulating_supply': 560000010.0064,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.07,
#   'ath_change_percentage': -40.62802,
#   'ath_date': '2021-05-12T14:37:47.535Z',
#   'atl': 0.04515276,
#   'atl_change_percentage': 5249.02989,
#   'atl_date': '2018-09-13T00:00:00.000Z',
#   'roi': {'times': 23.14577788759389,
#    'currency': 'usd',
#    'percentage': 2314.577788759389},
#   'last_updated': '2022-04-14T11:26:56.394Z'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'image': 'https://assets.coingecko.com/coins/images/8834/large/Chiliz.png?1561970540',
#   'current_price': 0.250319,
#   'market_cap': 1340211000,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 2229199608,
#   'total_volume': 491528143,
#   'high_24h': 0.258057,
#   'low_24h': 0.239774,
#   'price_change_24h': 0.0070904,
#   'price_change_percentage_24h': 2.91512,
#   'market_cap_change_24h': 45818693,
#   'market_cap_change_percentage_24h': 3.53978,
#   'circulating_supply': 5344064580.0,
#   'total_supply': 8888888888.0,
#   'max_supply': 8888888888.0,
#   'ath': 0.878633,
#   'ath_change_percentage': -71.49574,
#   'ath_date': '2021-03-13T08:04:21.200Z',
#   'atl': 0.00410887,
#   'atl_change_percentage': 5995.29129,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 10.378128498315004,
#    'currency': 'usd',
#    'percentage': 1037.8128498315004},
#   'last_updated': '2022-04-14T11:25:10.427Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'image': 'https://assets.coingecko.com/coins/images/2069/large/Stacks_logo_full.png?1604112510',
#   'current_price': 1.25,
#   'market_cap': 1327654586,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': None,
#   'total_volume': 32386091,
#   'high_24h': 1.28,
#   'low_24h': 1.17,
#   'price_change_24h': 0.067405,
#   'price_change_percentage_24h': 5.67768,
#   'market_cap_change_24h': 80739386,
#   'market_cap_change_percentage_24h': 6.47513,
#   'circulating_supply': 1052561461.68777,
#   'total_supply': 1352464600.0,
#   'max_supply': None,
#   'ath': 3.39,
#   'ath_change_percentage': -62.78787,
#   'ath_date': '2021-12-01T01:32:34.725Z',
#   'atl': 0.04559639,
#   'atl_change_percentage': 2666.35017,
#   'atl_date': '2020-03-13T02:29:26.415Z',
#   'roi': {'times': 9.454982049112783,
#    'currency': 'usd',
#    'percentage': 945.4982049112783},
#   'last_updated': '2022-04-14T11:24:50.509Z'},
#  {'id': 'stepn',
#   'symbol': 'gmt',
#   'name': 'STEPN',
#   'image': 'https://assets.coingecko.com/coins/images/23597/large/gmt.png?1644658792',
#   'current_price': 2.19,
#   'market_cap': 1315455795,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 13154557948,
#   'total_volume': 981736152,
#   'high_24h': 2.34,
#   'low_24h': 2.1,
#   'price_change_24h': 0.070877,
#   'price_change_percentage_24h': 3.34408,
#   'market_cap_change_24h': 45735358,
#   'market_cap_change_percentage_24h': 3.602,
#   'circulating_supply': 600000000.0,
#   'total_supply': 6000000000.0,
#   'max_supply': 6000000000.0,
#   'ath': 3.11,
#   'ath_change_percentage': -29.6661,
#   'ath_date': '2022-04-01T09:48:38.838Z',
#   'atl': 0.100826,
#   'atl_change_percentage': 2068.66858,
#   'atl_date': '2022-03-11T06:04:31.100Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:32.270Z'},
#  {'id': 'humans-ai',
#   'symbol': 'heart',
#   'name': 'Humans.ai',
#   'image': 'https://assets.coingecko.com/coins/images/21273/large/h_logo_1x.png?1638858402',
#   'current_price': 0.03190751,
#   'market_cap': 1309127902,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1309127902,
#   'total_volume': 1787345,
#   'high_24h': 0.0329612,
#   'low_24h': 0.0270543,
#   'price_change_24h': 0.0006685,
#   'price_change_percentage_24h': 2.13996,
#   'market_cap_change_24h': 1309127902,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 0.0,
#   'total_supply': 7800000000.0,
#   'max_supply': 7800000000.0,
#   'ath': 0.278557,
#   'ath_change_percentage': -88.54545,
#   'ath_date': '2021-12-26T18:32:54.961Z',
#   'atl': 0.0270543,
#   'atl_change_percentage': 17.93877,
#   'atl_date': '2022-04-13T12:41:24.676Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:24:11.000Z'},
#  {'id': 'havven',
#   'symbol': 'snx',
#   'name': 'Synthetix Network Token',
#   'image': 'https://assets.coingecko.com/coins/images/3406/large/SNX.png?1598631139',
#   'current_price': 5.45,
#   'market_cap': 1190959469,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 1381408621,
#   'total_volume': 108511961,
#   'high_24h': 5.58,
#   'low_24h': 4.92,
#   'price_change_24h': 0.426846,
#   'price_change_percentage_24h': 8.50239,
#   'market_cap_change_24h': 104847038,
#   'market_cap_change_percentage_24h': 9.65342,
#   'circulating_supply': 218449827.21024153,
#   'total_supply': 253382656.890449,
#   'max_supply': 253382656.890449,
#   'ath': 28.53,
#   'ath_change_percentage': -80.89229,
#   'ath_date': '2021-02-14T01:12:38.505Z',
#   'atl': 0.0347864,
#   'atl_change_percentage': 15572.4114,
#   'atl_date': '2019-01-06T00:00:00.000Z',
#   'roi': {'times': 9.89431032736112,
#    'currency': 'usd',
#    'percentage': 989.431032736112},
#   'last_updated': '2022-04-14T11:25:37.889Z'},
#  {'id': 'loopring',
#   'symbol': 'lrc',
#   'name': 'Loopring',
#   'image': 'https://assets.coingecko.com/coins/images/913/large/LRC.png?1572852344',
#   'current_price': 0.908345,
#   'market_cap': 1132955173,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 1249818050,
#   'total_volume': 109035247,
#   'high_24h': 0.946339,
#   'low_24h': 0.892647,
#   'price_change_24h': 0.00399054,
#   'price_change_percentage_24h': 0.44126,
#   'market_cap_change_24h': 10512432,
#   'market_cap_change_percentage_24h': 0.93657,
#   'circulating_supply': 1245991468.94246,
#   'total_supply': 1373873440.44246,
#   'max_supply': 1374513896.0,
#   'ath': 3.75,
#   'ath_change_percentage': -75.75151,
#   'ath_date': '2021-11-10T14:59:53.164Z',
#   'atl': 0.01963893,
#   'atl_change_percentage': 4529.9872,
#   'atl_date': '2019-12-18T13:14:41.553Z',
#   'roi': {'times': 14.139090759984606,
#    'currency': 'usd',
#    'percentage': 1413.9090759984606},
#   'last_updated': '2022-04-14T11:27:00.502Z'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'image': 'https://assets.coingecko.com/coins/images/19/large/dash-logo.png?1548385930',
#   'current_price': 104.47,
#   'market_cap': 1116849786,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': None,
#   'total_volume': 177428003,
#   'high_24h': 107.12,
#   'low_24h': 102.32,
#   'price_change_24h': 2.01,
#   'price_change_percentage_24h': 1.95945,
#   'market_cap_change_24h': 26477488,
#   'market_cap_change_percentage_24h': 2.4283,
#   'circulating_supply': 10674541.7683044,
#   'total_supply': 18920000.0,
#   'max_supply': None,
#   'ath': 1493.59,
#   'ath_change_percentage': -92.99491,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 0.213899,
#   'atl_change_percentage': 48814.40445,
#   'atl_date': '2014-02-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:21.252Z'},
#  {'id': 'amp-token',
#   'symbol': 'amp',
#   'name': 'Amp',
#   'image': 'https://assets.coingecko.com/coins/images/12409/large/amp-200x200.png?1599625397',
#   'current_price': 0.02318335,
#   'market_cap': 1113343148,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 2300825181,
#   'total_volume': 8653623,
#   'high_24h': 0.02378503,
#   'low_24h': 0.02298684,
#   'price_change_24h': 0.00012992,
#   'price_change_percentage_24h': 0.56357,
#   'market_cap_change_24h': 7672142,
#   'market_cap_change_percentage_24h': 0.69389,
#   'circulating_supply': 48013928909.1577,
#   'total_supply': 99443836655.394,
#   'max_supply': 99225164238.50153,
#   'ath': 0.120813,
#   'ath_change_percentage': -80.81644,
#   'ath_date': '2021-06-16T16:03:41.147Z',
#   'atl': 0.00250501,
#   'atl_change_percentage': 825.1917,
#   'atl_date': '2020-11-04T13:18:12.191Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:11.192Z'},
#  {'id': 'basic-attention-token',
#   'symbol': 'bat',
#   'name': 'Basic Attention Token',
#   'image': 'https://assets.coingecko.com/coins/images/677/large/basic-attention-token.png?1547034427',
#   'current_price': 0.738725,
#   'market_cap': 1107684795,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 1108272375,
#   'total_volume': 59053781,
#   'high_24h': 0.761404,
#   'low_24h': 0.713649,
#   'price_change_24h': 0.01832016,
#   'price_change_percentage_24h': 2.54304,
#   'market_cap_change_24h': 30250836,
#   'market_cap_change_percentage_24h': 2.80767,
#   'circulating_supply': 1499204734.8773506,
#   'total_supply': 1500000000.0,
#   'max_supply': 1500000000.0,
#   'ath': 1.9,
#   'ath_change_percentage': -61.12463,
#   'ath_date': '2021-11-28T00:23:51.354Z',
#   'atl': 0.072394,
#   'atl_change_percentage': 920.59595,
#   'atl_date': '2017-07-16T00:00:00.000Z',
#   'roi': {'times': 0.5320317085026618,
#    'currency': 'eth',
#    'percentage': 53.203170850266176},
#   'last_updated': '2022-04-14T11:25:48.736Z'},
#  {'id': 'mina-protocol',
#   'symbol': 'mina',
#   'name': 'Mina Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/15628/large/JM4_vQ34_400x400.png?1621394004',
#   'current_price': 2.4,
#   'market_cap': 1104246480,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 74564344,
#   'high_24h': 2.62,
#   'low_24h': 2.29,
#   'price_change_24h': 0.01361584,
#   'price_change_percentage_24h': 0.56998,
#   'market_cap_change_24h': 14313971,
#   'market_cap_change_percentage_24h': 1.31329,
#   'circulating_supply': 458875025.840039,
#   'total_supply': 909141292.840039,
#   'max_supply': None,
#   'ath': 9.09,
#   'ath_change_percentage': -73.57546,
#   'ath_date': '2021-06-01T01:42:37.064Z',
#   'atl': 0.925536,
#   'atl_change_percentage': 159.53423,
#   'atl_date': '2021-07-21T02:30:02.124Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:15.722Z'},
#  {'id': 'bitdao',
#   'symbol': 'bit',
#   'name': 'BitDAO',
#   'image': 'https://assets.coingecko.com/coins/images/17627/large/bitdao.jpg?1628679607',
#   'current_price': 1.19,
#   'market_cap': 1058083517,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 11886322804,
#   'total_volume': 30373252,
#   'high_24h': 1.21,
#   'low_24h': 1.15,
#   'price_change_24h': 0.02481007,
#   'price_change_percentage_24h': 2.13422,
#   'market_cap_change_24h': 23793814,
#   'market_cap_change_percentage_24h': 2.3005,
#   'circulating_supply': 890168922.860899,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 3.1,
#   'ath_change_percentage': -61.70979,
#   'ath_date': '2021-11-12T04:54:56.433Z',
#   'atl': 1.043,
#   'atl_change_percentage': 13.88841,
#   'atl_date': '2022-03-07T20:40:01.501Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:01.234Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'GateToken',
#   'image': 'https://assets.coingecko.com/coins/images/8183/large/gt.png?1556085624',
#   'current_price': 6.78,
#   'market_cap': 1030279805,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': None,
#   'total_volume': 8969668,
#   'high_24h': 6.78,
#   'low_24h': 6.43,
#   'price_change_24h': 0.33238,
#   'price_change_percentage_24h': 5.15582,
#   'market_cap_change_24h': 50999581,
#   'market_cap_change_percentage_24h': 5.20786,
#   'circulating_supply': 151758801.7378072,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 12.94,
#   'ath_change_percentage': -47.59821,
#   'ath_date': '2021-05-12T11:39:16.531Z',
#   'atl': 0.25754,
#   'atl_change_percentage': 2533.28411,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:26:07.926Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 152.02,
#   'market_cap': 1020223883,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 1520708673,
#   'total_volume': 278684022,
#   'high_24h': 155.67,
#   'low_24h': 129.08,
#   'price_change_24h': 21.7,
#   'price_change_percentage_24h': 16.651,
#   'market_cap_change_24h': 150642796,
#   'market_cap_change_percentage_24h': 17.32361,
#   'circulating_supply': 6708871.336854104,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 910.54,
#   'ath_change_percentage': -83.30323,
#   'ath_date': '2021-05-12T02:29:08.794Z',
#   'atl': 61.32,
#   'atl_change_percentage': 147.92303,
#   'atl_date': '2020-06-18T12:54:32.788Z',
#   'roi': None,
#   'last_updated': '2022-04-14T11:25:39.970Z'}]

# %%
# DefiLLama initialization & test
tvl = requests.get('https://api.llama.fi/protocol/aave').json()['tvl']
tvl[1]
# Out:
# {'date': 1578614400, 'totalLiquidityUSD': 481703.1835921449}

# %%
# Glassnode initialization
API_KEY = '27mKdxqslM3aORzuco6LoqzKjFc'

# make API request
res = requests.get('https://api.glassnode.com/v1/metrics/indicators/sopr',
    params={'a': 'BTC', 'api_key': API_KEY})

# convert to pandas dataframe
df = pd.read_json(res.text, convert_dates=['t'])
df.head()
# Out:
#            t         v
# 0 2010-07-17  1.000000
# 1 2010-07-18  1.174760
# 2 2010-07-19  1.318536
# 3 2010-07-20  1.090517
# 4 2010-07-21  1.065532
